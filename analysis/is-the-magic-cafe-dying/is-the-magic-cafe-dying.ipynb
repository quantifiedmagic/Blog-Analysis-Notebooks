# %% [markdown]
# # Is the Magic Café Dying?

# %%
import json
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = []
with open('../../data/themagiccafe_all_clean.jsonlines') as input_file:
    for row in input_file:
        data = json.loads(row)
        if 'title' not in data:
            continue
        if len(data['title']) < 2:
            continue
        for p in data['posts']:
            
            date = datetime.datetime.strptime(p['date'], 'Posted: %b %d, %Y %H:%M %p')
            dataset.append([date, data['title'][1]])
        
dataset = pd.DataFrame(dataset, columns=['date', 'forum'])

# %%
dataset['date'] = dataset['date'].astype('datetime64')
dataset['year'] = dataset['date'].dt.year
dataset['month'] = dataset['date'].dt.month
dataset['day'] = dataset['date'].dt.weekday

# %%
dataset.head()
# Out:
#                  date                 forum  year  month  day
# 0 2008-08-06 11:56:00  Paper money madness!  2008      8    2
# 1 2008-08-07 10:42:00  Paper money madness!  2008      8    3
# 2 2008-08-07 05:04:00  Paper money madness!  2008      8    3
# 3 2008-08-07 10:03:00  Paper money madness!  2008      8    3
# 4 2008-08-19 05:57:00  Paper money madness!  2008      8    1

# %%
dataset[dataset['forum'] == 'The workers'].head()
# Out:
#                        date        forum  year  month  day
# 4833298 2004-02-15 10:07:00  The workers  2004      2    6
# 4833299 2004-02-15 10:13:00  The workers  2004      2    6
# 4833300 2004-02-16 02:19:00  The workers  2004      2    0
# 4833301 2004-02-16 07:11:00  The workers  2004      2    0
# 4833302 2004-02-16 07:35:00  The workers  2004      2    0

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='year', data=dataset, color='#6890F0')
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.xlabel('Year', fontweight='light', fontsize=18)
plt.ylabel('Post Count', fontweight='light', fontsize=18)
plt.annotate( 'Last Special Guest', xy=(15,130000), xytext=(18, 250000), ha='right',  va="center",\
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=-0.2"))
plt.annotate( 'r/Magic Created', xy=(7,510000), xytext=(12, 500000), ha='right',  va="center",\
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=-0.2"))
# https://www.theory11.com/forums/
plt.annotate( 'Theory11 Forum Started', xy=(6,500000), xytext=(5, 500000), ha='right',  va="center",\
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=-0.2"))
plt.title('Magic Café Posts across Time', fontsize=24)
plt.savefig('magic-cafe-time.png')

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='month', data=dataset, color='#6890F0')
chart.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.xlabel('Year', fontweight='light', fontsize=18)
plt.ylabel('Post Count', fontweight='light', fontsize=18)
plt.title('Total Posts each Month', fontsize=24)
plt.savefig('magiccafe-month.png')

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='day', data=dataset, color='#6890F0')
chart.set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.xlabel('Month', fontweight='light', fontsize=18)
plt.ylabel('Post Count', fontweight='light', fontsize=18)
plt.title('Total Posts each Day', fontsize=24)
plt.savefig('magiccafe-days.png')

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='year', data=dataset[dataset['forum'] == 'The workers'], color='#6890F0')
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.xlabel('Year', fontweight='light', fontsize=18)
plt.ylabel('Post Count', fontweight='light', fontsize=18)

plt.title('Card Magic Posts over Time', fontsize=24)
plt.savefig('workers-time.png')

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='year', data=dataset[dataset['forum'] == 'Penny for your thoughts'], color='#6890F0')
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.xlabel('Year', fontweight='light', fontsize=18)
plt.ylabel('Post Count', fontweight='light', fontsize=18)

plt.title('Mentalism Posts over Time', fontsize=24)
plt.savefig('mental-time.png')

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='year', data=dataset[dataset['forum'] == 'Tricky business'], color='#6890F0')
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.xlabel('Year', fontweight='light', fontsize=18)
plt.ylabel('Post Count', fontweight='light', fontsize=18)

plt.title('Magic Business across Time', fontsize=24)
plt.savefig('bus-time.png')

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='year', data=dataset[dataset['forum'] == 'The little darlings'], color='#6890F0')
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.yticks( 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.xlabel('Year', fontweight='light', fontsize=18)
plt.ylabel('Post Count', fontweight='light', fontsize=18)

plt.title('Kids Magic over Time', fontsize=24)
plt.savefig('kids-time.png')
